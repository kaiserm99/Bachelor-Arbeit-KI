# %% [markdown]
# Visualisieren:
# ../../libMultiRobotPlanning-master/example/visualize.py test.yaml output.yaml
#
#
# Basic Info:
# [North, East, South, West]
# DO_NOTHING= 0 MOVE_FORWARD= 2 MOVE_LEFT= 1 MOVE_RIGHT= 3 STOP_MOVING= 4

# %%
import time


from flatland.core.env_observation_builder import ObservationBuilder
from flatland.envs.rail_env import RailEnv
from flatland.utils.rendertools import RenderTool
from flatland.core.grid.grid4_utils import get_new_position
from flatland.envs.rail_generators import sparse_rail_generator
from flatland.envs.schedule_generators import sparse_schedule_generator
from flatland.envs.rail_generators import rail_from_file


direction_to_str = {-1 : "pass...", 0: "North", 1: "East", 2: "South", 3: "West"}
action_to_str = {-1 : "pass...", 0 : "Do nothing", 1: "Left", 2 : "Forward", 3 : "Right", 4 : "Stop moving"}

# %%
# 20, 30, 3
# 25, 25, 5

render = True
print_more_info = False

try:
    
    speed_ration_map = {1.: 0.25,  # Fast passenger train
                    1. / 2.: 0.25,  # Fast freight train
                    1. / 3.: 0.25,  # Slow commuter train
                    1. / 4.: 0.25}  # Slow freight train
    
    env = RailEnv(width=50,
              height=50,
              rail_generator=sparse_rail_generator(
                  max_num_cities = 5,
                  grid_mode= False,
                  max_rails_between_cities = 5,
                  max_rails_in_city = 5, 
                  seed=10
              ),
              schedule_generator=sparse_schedule_generator(speed_ration_map),
              number_of_agents=8
    )

    
    _, info = env.reset()
    
    
    # Just do one dummy step so the Trains get a Position. My assumtion is, that it is always the same
    _, _, _, info = env.step({i : 2 for i in range(env.get_num_agents())})
    
    # Check if the result of the prioritized planning is valied
    res = pp(env, info)
    if res == -1: raise Stop

    # For rendering the Environment and the steps done by the agents
    if render: 
        env_renderer = RenderTool(env, screen_width=2000, screen_height=2000)
        env_renderer.render_env(show=True, frames=False, show_observations=False, show_predictions=False)
    
    # Empty action dictionary which has the predicted actions in it for each step
    action_dict = dict()
    
    pred_pos = dict()
    
    # For Loop with all the steps predicted by the agent
    for step in range(2000):
        # print(info)

        for handle in range(env.get_num_agents()):
        
            actions = res[handle]
            
            """
            print({env.agents[handle].speed_data["position_fraction"]})
            print(env.agents[handle].speed_data["transition_action_on_cellexit"])
            """
            
            if not actions.is_empty() and info['action_required'][handle]:
                action, pred_position = actions.pop(0)
                action_dict[handle] = action
                pred_pos[handle] = pred_position
                
                env.dev_pred_dict[handle] = actions.positions


            else:
                action_dict[handle] = 0
        
        # Do the actual step in the Enviroment based on the action_dict computed previously 
        obs, all_rewards, done, info = env.step(action_dict)

        # Print the current status of the agents in each iteration
        print(f"[{step+1:3}] In goal: {[handle for handle, status in done.items() if status]}")
        
        for handle, position in pred_pos.items():
            print(f"Aktuelle Position: {env.agents[handle].position}, gelangt nach: {pred_pos[handle]}, {env.agents[handle].speed_data['position_fraction'] / env.agents[handle].speed_data['speed']}")

        
        
        if print_more_info:
            print("Iteration:", step)
            for handle, action in action_dict.items():
                print(f"<{handle}> Action: |{action}|, Position: {env.agents[handle].position}, Target: {env.agents[handle].target}, Direction: {direction_to_str[env.agents[handle].direction]}")
                

        if render: 
            env_renderer.render_env(show=True, frames=False, show_observations=False, show_predictions=True)
            time.sleep(0.05)

        if done["__all__"]:
            print(f"\nAll Agents are in their targets! After {step+1} iterations.")
            break
            
finally:
    if render : env_renderer.close_window()
# Out:
# Checking if the starting positions are valid...
# The positions for the 0 Step is not valid. Try one more step...
# The positions are valid! Start searching...
#
# Agent:  5 starting from: (22, 11) - heading to: (32, 24), speed: 1 --> in 0.102415sec
# Agent:  0 starting from: (33, 25) - heading to: (11, 40), speed: 2 --> in 0.002132sec
# Agent:  4 starting from: (18, 25) - heading to: (32, 24), speed: 2 --> in 0.000462sec
# Agent:  6 starting from: (10, 40) - heading to: (17, 26), speed: 3 --> in 0.003843sec
# Agent:  2 starting from: (31, 23) - heading to: (34, 38), speed: 3 --> in 0.008105sec
# Agent:  1 starting from: (10, 39) - heading to: (36, 38), speed: 3 --> in 0.061646sec
# Agent:  3 starting from: (12, 39) - heading to: (32, 24), speed: 4 --> in 0.140902sec
# Agent:  7 starting from: (17, 25) - heading to: (13, 40), speed: 4 --> in 0.024846sec
# open_window - pyglet
# [  1] In goal: []
# Aktuelle Position: (33, 25), gelangt nach: (34, 25), 1.0
# Aktuelle Position: (10, 39), gelangt nach: (10, 38), 1.0
# Aktuelle Position: (31, 23), gelangt nach: (30, 23), 1.0
# Aktuelle Position: (12, 39), gelangt nach: (12, 38), 1.0
# Aktuelle Position: (18, 25), gelangt nach: (19, 25), 1.0
# Aktuelle Position: (22, 12), gelangt nach: (22, 12), 0.0
# Aktuelle Position: (10, 40), gelangt nach: (10, 41), 1.0
# Aktuelle Position: (17, 25), gelangt nach: (16, 25), 3.0
# [  2] In goal: []
# Aktuelle Position: (34, 25), gelangt nach: (34, 25), 0.0
# Aktuelle Position: (10, 39), gelangt nach: (10, 38), 2.0
# Aktuelle Position: (31, 23), gelangt nach: (30, 23), 2.0
# Aktuelle Position: (12, 39), gelangt nach: (12, 38), 2.0
# Aktuelle Position: (19, 25), gelangt nach: (19, 25), 0.0
# Aktuelle Position: (22, 13), gelangt nach: (22, 13), 0.0
# Aktuelle Position: (10, 40), gelangt nach: (10, 41), 2.0
# Aktuelle Position: (16, 25), gelangt nach: (16, 25), 0.0
# [  3] In goal: []
# Aktuelle Position: (34, 25), gelangt nach: (34, 24), 1.0
# Aktuelle Position: (10, 38), gelangt nach: (10, 38), 0.0
# Aktuelle Position: (30, 23), gelangt nach: (30, 23), 0.0
# Aktuelle Position: (12, 39), gelangt nach: (12, 38), 3.0
# Aktuelle Position: (19, 25), gelangt nach: (20, 25), 1.0
# Aktuelle Position: (22, 14), gelangt nach: (22, 14), 0.0
# Aktuelle Position: (10, 41), gelangt nach: (10, 41), 0.0
# Aktuelle Position: (16, 25), gelangt nach: (15, 25), 1.0
# [  4] In goal: []
# Aktuelle Position: (34, 24), gelangt nach: (34, 24), 0.0
# Aktuelle Position: (10, 38), gelangt nach: (11, 38), 1.0
# Aktuelle Position: (30, 23), gelangt nach: (29, 23), 1.0
# Aktuelle Position: (12, 38), gelangt nach: (12, 38), 0.0
# Aktuelle Position: (20, 25), gelangt nach: (20, 25), 0.0
# Aktuelle Position: (22, 15), gelangt nach: (22, 15), 0.0
# Aktuelle Position: (10, 41), gelangt nach: (10, 42), 1.0
# Aktuelle Position: (16, 25), gelangt nach: (15, 25), 2.0
# [  5] In goal: []
# Aktuelle Position: (34, 24), gelangt nach: (35, 24), 1.0
# Aktuelle Position: (10, 38), gelangt nach: (11, 38), 2.0
# Aktuelle Position: (30, 23), gelangt nach: (29, 23), 2.0
# Aktuelle Position: (12, 38), gelangt nach: (12, 37), 1.0
# Aktuelle Position: (20, 25), gelangt nach: (21, 25), 1.0
# Aktuelle Position: (22, 16), gelangt nach: (22, 16), 0.0
# Aktuelle Position: (10, 41), gelangt nach: (10, 42), 2.0
# Aktuelle Position: (16, 25), gelangt nach: (15, 25), 3.0
# [  6] In goal: []
# Aktuelle Position: (35, 24), gelangt nach: (35, 24), 0.0
# Aktuelle Position: (11, 38), gelangt nach: (11, 38), 0.0
# Aktuelle Position: (29, 23), gelangt nach: (29, 23), 0.0
# Aktuelle Position: (12, 38), gelangt nach: (12, 37), 2.0
# Aktuelle Position: (21, 25), gelangt nach: (21, 25), 0.0
# Aktuelle Position: (21, 16), gelangt nach: (21, 16), 0.0
# Aktuelle Position: (10, 42), gelangt nach: (10, 42), 0.0
# Aktuelle Position: (15, 25), gelangt nach: (15, 25), 0.0
# [  7] In goal: []
# Aktuelle Position: (35, 24), gelangt nach: (36, 24), 1.0
# Aktuelle Position: (11, 38), gelangt nach: (11, 37), 1.0
# Aktuelle Position: (29, 23), gelangt nach: (29, 23), 0.0
# Aktuelle Position: (12, 38), gelangt nach: (12, 37), 3.0
# Aktuelle Position: (21, 25), gelangt nach: (21, 24), 1.0
# Aktuelle Position: (20, 16), gelangt nach: (20, 16), 0.0
# Aktuelle Position: (10, 42), gelangt nach: (11, 42), 1.0
# Aktuelle Position: (15, 25), gelangt nach: (14, 25), 1.0
# [  8] In goal: []
# Aktuelle Position: (36, 24), gelangt nach: (36, 24), 0.0
# Aktuelle Position: (11, 38), gelangt nach: (11, 37), 2.0
# Aktuelle Position: (29, 23), gelangt nach: (29, 23), 0.0
# Aktuelle Position: (12, 37), gelangt nach: (12, 37), 0.0
# Aktuelle Position: (21, 24), gelangt nach: (21, 24), 0.0
# Aktuelle Position: (19, 16), gelangt nach: (19, 16), 0.0
# Aktuelle Position: (10, 42), gelangt nach: (11, 42), 2.0
# Aktuelle Position: (15, 25), gelangt nach: (14, 25), 2.0
# [  9] In goal: []
# Aktuelle Position: (36, 24), gelangt nach: (37, 24), 1.0
# Aktuelle Position: (11, 37), gelangt nach: (11, 37), 0.0
# Aktuelle Position: (29, 23), gelangt nach: (29, 23), 0.0
# Aktuelle Position: (12, 37), gelangt nach: (12, 36), 1.0
# Aktuelle Position: (21, 24), gelangt nach: (22, 24), 1.0
# Aktuelle Position: (18, 16), gelangt nach: (18, 16), 0.0
# Aktuelle Position: (11, 42), gelangt nach: (11, 42), 0.0
# Aktuelle Position: (15, 25), gelangt nach: (14, 25), 3.0
# [ 10] In goal: []
# Aktuelle Position: (37, 24), gelangt nach: (37, 24), 0.0
# Aktuelle Position: (11, 37), gelangt nach: (11, 36), 1.0
# Aktuelle Position: (29, 23), gelangt nach: (29, 23), 0.0
# Aktuelle Position: (12, 37), gelangt nach: (12, 36), 2.0
# Aktuelle Position: (22, 24), gelangt nach: (22, 24), 0.0
# Aktuelle Position: (17, 16), gelangt nach: (17, 16), 0.0
# Aktuelle Position: (11, 42), gelangt nach: (11, 43), 1.0
# Aktuelle Position: (14, 25), gelangt nach: (14, 25), 0.0
# [ 11] In goal: []
# Aktuelle Position: (37, 24), gelangt nach: (38, 24), 1.0
# Aktuelle Position: (11, 37), gelangt nach: (11, 36), 2.0
# Aktuelle Position: (29, 23), gelangt nach: (29, 23), 0.0
# Aktuelle Position: (12, 37), gelangt nach: (12, 36), 3.0
# Aktuelle Position: (22, 24), gelangt nach: (23, 24), 1.0
# Aktuelle Position: (16, 16), gelangt nach: (16, 16), 0.0
# Aktuelle Position: (11, 42), gelangt nach: (11, 43), 2.0
# Aktuelle Position: (14, 25), gelangt nach: (13, 25), 1.0
# [ 12] In goal: []
# Aktuelle Position: (38, 24), gelangt nach: (38, 24), 0.0
# Aktuelle Position: (11, 36), gelangt nach: (11, 36), 0.0
# Aktuelle Position: (29, 23), gelangt nach: (29, 23), 0.0
# Aktuelle Position: (12, 36), gelangt nach: (12, 36), 0.0
# Aktuelle Position: (23, 24), gelangt nach: (23, 24), 0.0
# Aktuelle Position: (15, 16), gelangt nach: (15, 16), 0.0
# Aktuelle Position: (11, 43), gelangt nach: (11, 43), 0.0
# Aktuelle Position: (14, 25), gelangt nach: (13, 25), 2.0
# [ 13] In goal: []
# Aktuelle Position: (38, 24), gelangt nach: (38, 25), 1.0
# Aktuelle Position: (11, 36), gelangt nach: (11, 35), 1.0
# Aktuelle Position: (29, 23), gelangt nach: (29, 23), 0.0
# Aktuelle Position: (12, 36), gelangt nach: (12, 35), 1.0
# Aktuelle Position: (23, 24), gelangt nach: (24, 24), 1.0
# Aktuelle Position: (14, 16), gelangt nach: (14, 16), 0.0
# Aktuelle Position: (11, 43), gelangt nach: (11, 44), 1.0
# Aktuelle Position: (14, 25), gelangt nach: (13, 25), 3.0
# [ 14] In goal: []
# Aktuelle Position: (38, 25), gelangt nach: (38, 25), 0.0
# Aktuelle Position: (11, 36), gelangt nach: (11, 35), 2.0
# Aktuelle Position: (29, 23), gelangt nach: (29, 23), 0.0
# Aktuelle Position: (12, 36), gelangt nach: (12, 35), 2.0
# Aktuelle Position: (24, 24), gelangt nach: (24, 24), 0.0
# Aktuelle Position: (13, 16), gelangt nach: (13, 16), 0.0
# Aktuelle Position: (11, 43), gelangt nach: (11, 44), 2.0
# Aktuelle Position: (13, 25), gelangt nach: (13, 25), 0.0
# [ 15] In goal: []
# Aktuelle Position: (38, 25), gelangt nach: (38, 26), 1.0
# Aktuelle Position: (11, 35), gelangt nach: (11, 35), 0.0
# Aktuelle Position: (29, 23), gelangt nach: (29, 23), 0.0
# Aktuelle Position: (12, 36), gelangt nach: (12, 35), 3.0
# Aktuelle Position: (24, 24), gelangt nach: (25, 24), 1.0
# Aktuelle Position: (12, 16), gelangt nach: (12, 16), 0.0
# Aktuelle Position: (11, 44), gelangt nach: (11, 44), 0.0
# Aktuelle Position: (13, 25), gelangt nach: (13, 25), 0.0
# [ 16] In goal: []
# Aktuelle Position: (38, 26), gelangt nach: (38, 26), 0.0
# Aktuelle Position: (11, 35), gelangt nach: (11, 34), 1.0
# Aktuelle Position: (29, 23), gelangt nach: (29, 23), 0.0
# Aktuelle Position: (12, 35), gelangt nach: (12, 35), 0.0
# Aktuelle Position: (25, 24), gelangt nach: (25, 24), 0.0
# Aktuelle Position: (11, 16), gelangt nach: (11, 16), 0.0
# Aktuelle Position: (11, 44), gelangt nach: (11, 45), 1.0
# Aktuelle Position: (13, 25), gelangt nach: (13, 25), 0.0
# [ 17] In goal: []
# Aktuelle Position: (38, 26), gelangt nach: (38, 27), 1.0
# Aktuelle Position: (11, 35), gelangt nach: (11, 34), 2.0
# Aktuelle Position: (29, 23), gelangt nach: (29, 23), 0.0
# Aktuelle Position: (12, 35), gelangt nach: (12, 34), 1.0
# Aktuelle Position: (25, 24), gelangt nach: (26, 24), 1.0
# Aktuelle Position: (11, 17), gelangt nach: (11, 17), 0.0
# Aktuelle Position: (11, 44), gelangt nach: (11, 45), 2.0
# Aktuelle Position: (13, 25), gelangt nach: (13, 25), 0.0
# [ 18] In goal: []
# Aktuelle Position: (38, 27), gelangt nach: (38, 27), 0.0
# Aktuelle Position: (11, 34), gelangt nach: (11, 34), 0.0
# Aktuelle Position: (29, 23), gelangt nach: (29, 23), 0.0
# Aktuelle Position: (12, 35), gelangt nach: (12, 34), 2.0
# Aktuelle Position: (26, 24), gelangt nach: (26, 24), 0.0
# Aktuelle Position: (11, 18), gelangt nach: (11, 18), 0.0
# Aktuelle Position: (11, 45), gelangt nach: (11, 45), 0.0
# Aktuelle Position: (13, 25), gelangt nach: (13, 25), 0.0
# [ 19] In goal: []
# Aktuelle Position: (38, 27), gelangt nach: (38, 28), 1.0
# Aktuelle Position: (11, 34), gelangt nach: (11, 33), 1.0
# Aktuelle Position: (29, 23), gelangt nach: (29, 23), 0.0
# Aktuelle Position: (12, 35), gelangt nach: (12, 34), 3.0
# Aktuelle Position: (26, 24), gelangt nach: (27, 24), 1.0
# Aktuelle Position: (11, 19), gelangt nach: (11, 19), 0.0
# Aktuelle Position: (11, 45), gelangt nach: (11, 46), 1.0
# Aktuelle Position: (13, 25), gelangt nach: (13, 25), 0.0
# [ 20] In goal: []
# Aktuelle Position: (38, 28), gelangt nach: (38, 28), 0.0
# Aktuelle Position: (11, 34), gelangt nach: (11, 33), 2.0
# Aktuelle Position: (29, 23), gelangt nach: (29, 23), 0.0
# Aktuelle Position: (12, 34), gelangt nach: (12, 34), 0.0
# Aktuelle Position: (27, 24), gelangt nach: (27, 24), 0.0
# Aktuelle Position: (11, 20), gelangt nach: (11, 20), 0.0
# Aktuelle Position: (11, 45), gelangt nach: (11, 46), 2.0
# Aktuelle Position: (13, 25), gelangt nach: (13, 25), 0.0
# [ 21] In goal: []
# Aktuelle Position: (38, 28), gelangt nach: (38, 29), 1.0
# Aktuelle Position: (11, 33), gelangt nach: (11, 33), 0.0
# Aktuelle Position: (29, 23), gelangt nach: (29, 23), 0.0
# Aktuelle Position: (12, 34), gelangt nach: (12, 33), 1.0
# Aktuelle Position: (27, 24), gelangt nach: (28, 24), 1.0
# Aktuelle Position: (11, 21), gelangt nach: (11, 21), 0.0
# Aktuelle Position: (11, 46), gelangt nach: (11, 46), 0.0
# Aktuelle Position: (13, 25), gelangt nach: (13, 25), 0.0
# [ 22] In goal: []
# Aktuelle Position: (38, 29), gelangt nach: (38, 29), 0.0
# Aktuelle Position: (11, 33), gelangt nach: (11, 32), 1.0
# Aktuelle Position: (29, 23), gelangt nach: (29, 23), 0.0
# Aktuelle Position: (12, 34), gelangt nach: (12, 33), 2.0
# Aktuelle Position: (28, 24), gelangt nach: (28, 24), 0.0
# Aktuelle Position: (11, 22), gelangt nach: (11, 22), 0.0
# Aktuelle Position: (11, 46), gelangt nach: (12, 46), 1.0
# Aktuelle Position: (13, 25), gelangt nach: (13, 25), 0.0
# [ 23] In goal: []
# Aktuelle Position: (38, 29), gelangt nach: (38, 30), 1.0
# Aktuelle Position: (11, 33), gelangt nach: (11, 32), 2.0
# Aktuelle Position: (29, 23), gelangt nach: (29, 23), 0.0
# Aktuelle Position: (12, 34), gelangt nach: (12, 33), 3.0
# Aktuelle Position: (28, 24), gelangt nach: (29, 24), 1.0
# Aktuelle Position: (11, 23), gelangt nach: (11, 23), 0.0
# Aktuelle Position: (11, 46), gelangt nach: (12, 46), 2.0
# Aktuelle Position: (13, 25), gelangt nach: (13, 25), 0.0
# [ 24] In goal: []
# Aktuelle Position: (38, 30), gelangt nach: (38, 30), 0.0
# Aktuelle Position: (11, 32), gelangt nach: (11, 32), 0.0
# Aktuelle Position: (29, 23), gelangt nach: (29, 23), 0.0
# Aktuelle Position: (12, 33), gelangt nach: (12, 33), 0.0
# Aktuelle Position: (29, 24), gelangt nach: (29, 24), 0.0
# Aktuelle Position: (11, 24), gelangt nach: (11, 24), 0.0
# Aktuelle Position: (12, 46), gelangt nach: (12, 46), 0.0
# Aktuelle Position: (13, 25), gelangt nach: (13, 25), 0.0
# [ 25] In goal: []
# Aktuelle Position: (38, 30), gelangt nach: (37, 30), 1.0
# Aktuelle Position: (11, 32), gelangt nach: (11, 31), 1.0
# Aktuelle Position: (29, 23), gelangt nach: (29, 23), 0.0
# Aktuelle Position: (12, 33), gelangt nach: (12, 32), 1.0
# Aktuelle Position: (29, 24), gelangt nach: (30, 24), 1.0
# Aktuelle Position: (12, 24), gelangt nach: (12, 24), 0.0
# Aktuelle Position: (12, 46), gelangt nach: (13, 46), 1.0
# Aktuelle Position: (13, 25), gelangt nach: (13, 25), 0.0
# [ 26] In goal: []
# Aktuelle Position: (37, 30), gelangt nach: (37, 30), 0.0
# Aktuelle Position: (11, 32), gelangt nach: (11, 31), 2.0
# Aktuelle Position: (29, 23), gelangt nach: (29, 23), 0.0
# Aktuelle Position: (12, 33), gelangt nach: (12, 32), 2.0
# Aktuelle Position: (30, 24), gelangt nach: (30, 24), 0.0
# Aktuelle Position: (13, 24), gelangt nach: (13, 24), 0.0
# Aktuelle Position: (12, 46), gelangt nach: (13, 46), 2.0
# Aktuelle Position: (13, 25), gelangt nach: (13, 25), 0.0
# [ 27] In goal: []
# Aktuelle Position: (37, 30), gelangt nach: (36, 30), 1.0
# Aktuelle Position: (11, 31), gelangt nach: (11, 31), 0.0
# Aktuelle Position: (29, 23), gelangt nach: (29, 23), 0.0
# Aktuelle Position: (12, 33), gelangt nach: (12, 32), 3.0
# Aktuelle Position: (30, 24), gelangt nach: (31, 24), 1.0
# Aktuelle Position: (14, 24), gelangt nach: (14, 24), 0.0
# Aktuelle Position: (13, 46), gelangt nach: (13, 46), 0.0
# Aktuelle Position: (13, 25), gelangt nach: (13, 25), 0.0
# [ 28] In goal: []
# Aktuelle Position: (36, 30), gelangt nach: (36, 30), 0.0
# Aktuelle Position: (11, 31), gelangt nach: (11, 30), 1.0
# Aktuelle Position: (29, 23), gelangt nach: (29, 23), 0.0
# Aktuelle Position: (12, 32), gelangt nach: (12, 32), 0.0
# Aktuelle Position: (31, 24), gelangt nach: (31, 24), 0.0
# Aktuelle Position: (15, 24), gelangt nach: (15, 24), 0.0
# Aktuelle Position: (13, 46), gelangt nach: (14, 46), 1.0
# Aktuelle Position: (13, 25), gelangt nach: (13, 25), 0.0
# [ 29] In goal: []
# Aktuelle Position: (36, 30), gelangt nach: (35, 30), 1.0
# Aktuelle Position: (11, 31), gelangt nach: (11, 30), 2.0
# Aktuelle Position: (29, 23), gelangt nach: (29, 23), 0.0
# Aktuelle Position: (12, 32), gelangt nach: (12, 31), 1.0
# Aktuelle Position: (31, 24), gelangt nach: (32, 24), 1.0
# Aktuelle Position: (16, 24), gelangt nach: (16, 24), 0.0
# Aktuelle Position: (13, 46), gelangt nach: (14, 46), 2.0
# Aktuelle Position: (13, 25), gelangt nach: (13, 25), 0.0
# [ 30] In goal: [4]
# Aktuelle Position: (35, 30), gelangt nach: (35, 30), 0.0
# Aktuelle Position: (11, 30), gelangt nach: (11, 30), 0.0
# Aktuelle Position: (29, 23), gelangt nach: (29, 23), 0.0
# Aktuelle Position: (12, 32), gelangt nach: (12, 31), 2.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: (17, 24), gelangt nach: (17, 24), 0.0
# Aktuelle Position: (14, 46), gelangt nach: (14, 46), 0.0
# Aktuelle Position: (13, 25), gelangt nach: (13, 25), 0.0
# [ 31] In goal: [4]
# Aktuelle Position: (35, 30), gelangt nach: (34, 30), 1.0
# Aktuelle Position: (11, 30), gelangt nach: (11, 29), 1.0
# Aktuelle Position: (29, 23), gelangt nach: (29, 23), 0.0
# Aktuelle Position: (12, 32), gelangt nach: (12, 31), 3.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: (18, 24), gelangt nach: (18, 24), 0.0
# Aktuelle Position: (14, 46), gelangt nach: (15, 46), 1.0
# Aktuelle Position: (13, 25), gelangt nach: (13, 25), 0.0
# [ 32] In goal: [4]
# Aktuelle Position: (34, 30), gelangt nach: (34, 30), 0.0
# Aktuelle Position: (11, 30), gelangt nach: (11, 29), 2.0
# Aktuelle Position: (29, 23), gelangt nach: (29, 23), 0.0
# Aktuelle Position: (12, 31), gelangt nach: (12, 31), 0.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: (19, 24), gelangt nach: (19, 24), 0.0
# Aktuelle Position: (14, 46), gelangt nach: (15, 46), 2.0
# Aktuelle Position: (13, 25), gelangt nach: (13, 25), 0.0
# [ 33] In goal: [4]
# Aktuelle Position: (34, 30), gelangt nach: (33, 30), 1.0
# Aktuelle Position: (11, 29), gelangt nach: (11, 29), 0.0
# Aktuelle Position: (29, 23), gelangt nach: (29, 23), 0.0
# Aktuelle Position: (12, 31), gelangt nach: (12, 30), 1.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: (20, 24), gelangt nach: (20, 24), 0.0
# Aktuelle Position: (15, 46), gelangt nach: (15, 46), 0.0
# Aktuelle Position: (13, 25), gelangt nach: (13, 25), 0.0
# [ 34] In goal: [4]
# Aktuelle Position: (33, 30), gelangt nach: (33, 30), 0.0
# Aktuelle Position: (11, 29), gelangt nach: (11, 28), 1.0
# Aktuelle Position: (29, 23), gelangt nach: (29, 23), 0.0
# Aktuelle Position: (12, 31), gelangt nach: (12, 30), 2.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: (21, 24), gelangt nach: (21, 24), 0.0
# Aktuelle Position: (15, 46), gelangt nach: (16, 46), 1.0
# Aktuelle Position: (13, 25), gelangt nach: (13, 25), 0.0
# [ 35] In goal: [4]
# Aktuelle Position: (33, 30), gelangt nach: (33, 31), 1.0
# Aktuelle Position: (11, 29), gelangt nach: (11, 28), 2.0
# Aktuelle Position: (29, 23), gelangt nach: (29, 23), 0.0
# Aktuelle Position: (12, 31), gelangt nach: (12, 30), 3.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: (22, 24), gelangt nach: (22, 24), 0.0
# Aktuelle Position: (15, 46), gelangt nach: (16, 46), 2.0
# Aktuelle Position: (13, 25), gelangt nach: (13, 25), 0.0
# [ 36] In goal: [4]
# Aktuelle Position: (33, 31), gelangt nach: (33, 31), 0.0
# Aktuelle Position: (11, 28), gelangt nach: (11, 28), 0.0
# Aktuelle Position: (29, 23), gelangt nach: (29, 23), 0.0
# Aktuelle Position: (12, 30), gelangt nach: (12, 30), 0.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: (23, 24), gelangt nach: (23, 24), 0.0
# Aktuelle Position: (16, 46), gelangt nach: (16, 46), 0.0
# Aktuelle Position: (13, 25), gelangt nach: (13, 25), 0.0
# [ 37] In goal: [4]
# Aktuelle Position: (33, 31), gelangt nach: (33, 32), 1.0
# Aktuelle Position: (11, 28), gelangt nach: (11, 27), 1.0
# Aktuelle Position: (29, 23), gelangt nach: (29, 23), 0.0
# Aktuelle Position: (12, 30), gelangt nach: (11, 30), 1.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: (24, 24), gelangt nach: (24, 24), 0.0
# Aktuelle Position: (16, 46), gelangt nach: (17, 46), 1.0
# Aktuelle Position: (13, 25), gelangt nach: (13, 25), 0.0
# [ 38] In goal: [4]
# Aktuelle Position: (33, 32), gelangt nach: (33, 32), 0.0
# Aktuelle Position: (11, 28), gelangt nach: (11, 27), 2.0
# Aktuelle Position: (29, 23), gelangt nach: (29, 23), 0.0
# Aktuelle Position: (12, 30), gelangt nach: (11, 30), 2.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: (25, 24), gelangt nach: (25, 24), 0.0
# Aktuelle Position: (16, 46), gelangt nach: (17, 46), 2.0
# Aktuelle Position: (13, 25), gelangt nach: (13, 25), 0.0
# [ 39] In goal: [4]
# Aktuelle Position: (33, 32), gelangt nach: (33, 33), 1.0
# Aktuelle Position: (11, 27), gelangt nach: (11, 27), 0.0
# Aktuelle Position: (29, 23), gelangt nach: (29, 23), 0.0
# Aktuelle Position: (12, 30), gelangt nach: (11, 30), 3.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: (26, 24), gelangt nach: (26, 24), 0.0
# Aktuelle Position: (17, 46), gelangt nach: (17, 46), 0.0
# Aktuelle Position: (13, 25), gelangt nach: (13, 25), 0.0
# [ 40] In goal: [4]
# Aktuelle Position: (33, 33), gelangt nach: (33, 33), 0.0
# Aktuelle Position: (11, 27), gelangt nach: (11, 26), 1.0
# Aktuelle Position: (29, 23), gelangt nach: (29, 23), 0.0
# Aktuelle Position: (11, 30), gelangt nach: (11, 30), 0.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: (27, 24), gelangt nach: (27, 24), 0.0
# Aktuelle Position: (17, 46), gelangt nach: (18, 46), 1.0
# Aktuelle Position: (13, 25), gelangt nach: (13, 25), 0.0
# [ 41] In goal: [4]
# Aktuelle Position: (33, 33), gelangt nach: (33, 34), 1.0
# Aktuelle Position: (11, 27), gelangt nach: (11, 26), 2.0
# Aktuelle Position: (29, 23), gelangt nach: (29, 24), 1.0
# Aktuelle Position: (11, 30), gelangt nach: (11, 29), 1.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: (28, 24), gelangt nach: (28, 24), 0.0
# Aktuelle Position: (17, 46), gelangt nach: (18, 46), 2.0
# Aktuelle Position: (13, 25), gelangt nach: (13, 25), 0.0
# [ 42] In goal: [4]
# Aktuelle Position: (33, 34), gelangt nach: (33, 34), 0.0
# Aktuelle Position: (11, 26), gelangt nach: (11, 26), 0.0
# Aktuelle Position: (29, 23), gelangt nach: (29, 24), 2.0
# Aktuelle Position: (11, 30), gelangt nach: (11, 29), 2.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: (29, 24), gelangt nach: (29, 24), 0.0
# Aktuelle Position: (18, 46), gelangt nach: (18, 46), 0.0
# Aktuelle Position: (13, 25), gelangt nach: (13, 25), 0.0
# [ 43] In goal: [4]
# Aktuelle Position: (33, 34), gelangt nach: (33, 35), 1.0
# Aktuelle Position: (11, 26), gelangt nach: (11, 25), 1.0
# Aktuelle Position: (29, 24), gelangt nach: (29, 24), 0.0
# Aktuelle Position: (11, 30), gelangt nach: (11, 29), 3.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: (30, 24), gelangt nach: (30, 24), 0.0
# Aktuelle Position: (18, 46), gelangt nach: (19, 46), 1.0
# Aktuelle Position: (13, 25), gelangt nach: (13, 25), 0.0
# [ 44] In goal: [4]
# Aktuelle Position: (33, 35), gelangt nach: (33, 35), 0.0
# Aktuelle Position: (11, 26), gelangt nach: (11, 25), 2.0
# Aktuelle Position: (29, 24), gelangt nach: (28, 24), 1.0
# Aktuelle Position: (11, 29), gelangt nach: (11, 29), 0.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: (31, 24), gelangt nach: (31, 24), 0.0
# Aktuelle Position: (18, 46), gelangt nach: (19, 46), 2.0
# Aktuelle Position: (13, 25), gelangt nach: (13, 25), 0.0
# [ 45] In goal: [4, 5]
# Aktuelle Position: (33, 35), gelangt nach: (33, 36), 1.0
# Aktuelle Position: (11, 25), gelangt nach: (11, 25), 0.0
# Aktuelle Position: (29, 24), gelangt nach: (28, 24), 2.0
# Aktuelle Position: (11, 29), gelangt nach: (11, 28), 1.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: (19, 46), gelangt nach: (19, 46), 0.0
# Aktuelle Position: (13, 25), gelangt nach: (13, 25), 0.0
# [ 46] In goal: [4, 5]
# Aktuelle Position: (33, 36), gelangt nach: (33, 36), 0.0
# Aktuelle Position: (11, 25), gelangt nach: (11, 24), 1.0
# Aktuelle Position: (28, 24), gelangt nach: (28, 24), 0.0
# Aktuelle Position: (11, 29), gelangt nach: (11, 28), 2.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: (19, 46), gelangt nach: (20, 46), 1.0
# Aktuelle Position: (13, 25), gelangt nach: (13, 25), 0.0
# [ 47] In goal: [4, 5]
# Aktuelle Position: (33, 36), gelangt nach: (33, 37), 1.0
# Aktuelle Position: (11, 25), gelangt nach: (11, 24), 2.0
# Aktuelle Position: (28, 24), gelangt nach: (27, 24), 1.0
# Aktuelle Position: (11, 29), gelangt nach: (11, 28), 3.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: (19, 46), gelangt nach: (20, 46), 2.0
# Aktuelle Position: (13, 25), gelangt nach: (13, 25), 0.0
# [ 48] In goal: [4, 5]
# Aktuelle Position: (33, 37), gelangt nach: (33, 37), 0.0
# Aktuelle Position: (11, 24), gelangt nach: (11, 24), 0.0
# Aktuelle Position: (28, 24), gelangt nach: (27, 24), 2.0
# Aktuelle Position: (11, 28), gelangt nach: (11, 28), 0.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: (20, 46), gelangt nach: (20, 46), 0.0
# Aktuelle Position: (13, 25), gelangt nach: (13, 25), 0.0
# [ 49] In goal: [4, 5]
# Aktuelle Position: (33, 37), gelangt nach: (33, 38), 1.0
# Aktuelle Position: (11, 24), gelangt nach: (12, 24), 1.0
# Aktuelle Position: (27, 24), gelangt nach: (27, 24), 0.0
# Aktuelle Position: (11, 28), gelangt nach: (11, 27), 1.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: (20, 46), gelangt nach: (21, 46), 1.0
# Aktuelle Position: (13, 25), gelangt nach: (13, 25), 0.0
# [ 50] In goal: [4, 5]
# Aktuelle Position: (33, 38), gelangt nach: (33, 38), 0.0
# Aktuelle Position: (11, 24), gelangt nach: (12, 24), 2.0
# Aktuelle Position: (27, 24), gelangt nach: (26, 24), 1.0
# Aktuelle Position: (11, 28), gelangt nach: (11, 27), 2.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: (20, 46), gelangt nach: (21, 46), 2.0
# Aktuelle Position: (13, 25), gelangt nach: (13, 25), 0.0
# [ 51] In goal: [4, 5]
# Aktuelle Position: (33, 38), gelangt nach: (33, 39), 1.0
# Aktuelle Position: (12, 24), gelangt nach: (12, 24), 0.0
# Aktuelle Position: (27, 24), gelangt nach: (26, 24), 2.0
# Aktuelle Position: (11, 28), gelangt nach: (11, 27), 3.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: (21, 46), gelangt nach: (21, 46), 0.0
# Aktuelle Position: (13, 25), gelangt nach: (13, 25), 0.0
# [ 52] In goal: [4, 5]
# Aktuelle Position: (33, 39), gelangt nach: (33, 39), 0.0
# Aktuelle Position: (12, 24), gelangt nach: (13, 24), 1.0
# Aktuelle Position: (26, 24), gelangt nach: (26, 24), 0.0
# Aktuelle Position: (11, 27), gelangt nach: (11, 27), 0.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: (21, 46), gelangt nach: (22, 46), 1.0
# Aktuelle Position: (13, 25), gelangt nach: (13, 25), 0.0
# [ 53] In goal: [4, 5]
# Aktuelle Position: (33, 39), gelangt nach: (33, 40), 1.0
# Aktuelle Position: (12, 24), gelangt nach: (13, 24), 2.0
# Aktuelle Position: (26, 24), gelangt nach: (25, 24), 1.0
# Aktuelle Position: (11, 27), gelangt nach: (11, 26), 1.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: (21, 46), gelangt nach: (22, 46), 2.0
# Aktuelle Position: (13, 25), gelangt nach: (13, 25), 0.0
# [ 54] In goal: [4, 5]
# Aktuelle Position: (33, 40), gelangt nach: (33, 40), 0.0
# Aktuelle Position: (13, 24), gelangt nach: (13, 24), 0.0
# Aktuelle Position: (26, 24), gelangt nach: (25, 24), 2.0
# Aktuelle Position: (11, 27), gelangt nach: (11, 26), 2.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: (22, 46), gelangt nach: (22, 46), 0.0
# Aktuelle Position: (13, 25), gelangt nach: (13, 25), 0.0
# [ 55] In goal: [4, 5]
# Aktuelle Position: (33, 40), gelangt nach: (33, 41), 1.0
# Aktuelle Position: (13, 24), gelangt nach: (14, 24), 1.0
# Aktuelle Position: (25, 24), gelangt nach: (25, 24), 0.0
# Aktuelle Position: (11, 27), gelangt nach: (11, 26), 3.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: (22, 46), gelangt nach: (23, 46), 1.0
# Aktuelle Position: (13, 25), gelangt nach: (13, 25), 0.0
# [ 56] In goal: [4, 5]
# Aktuelle Position: (33, 41), gelangt nach: (33, 41), 0.0
# Aktuelle Position: (13, 24), gelangt nach: (14, 24), 2.0
# Aktuelle Position: (25, 24), gelangt nach: (24, 24), 1.0
# Aktuelle Position: (11, 26), gelangt nach: (11, 26), 0.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: (22, 46), gelangt nach: (23, 46), 2.0
# Aktuelle Position: (13, 25), gelangt nach: (13, 25), 0.0
# [ 57] In goal: [4, 5]
# Aktuelle Position: (33, 41), gelangt nach: (33, 42), 1.0
# Aktuelle Position: (14, 24), gelangt nach: (14, 24), 0.0
# Aktuelle Position: (25, 24), gelangt nach: (24, 24), 2.0
# Aktuelle Position: (11, 26), gelangt nach: (11, 25), 1.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: (23, 46), gelangt nach: (23, 46), 0.0
# Aktuelle Position: (13, 25), gelangt nach: (13, 25), 0.0
# [ 58] In goal: [4, 5]
# Aktuelle Position: (33, 42), gelangt nach: (33, 42), 0.0
# Aktuelle Position: (14, 24), gelangt nach: (15, 24), 1.0
# Aktuelle Position: (24, 24), gelangt nach: (24, 24), 0.0
# Aktuelle Position: (11, 26), gelangt nach: (11, 25), 2.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: (23, 46), gelangt nach: (24, 46), 1.0
# Aktuelle Position: (13, 25), gelangt nach: (13, 25), 0.0
# [ 59] In goal: [4, 5]
# Aktuelle Position: (33, 42), gelangt nach: (33, 43), 1.0
# Aktuelle Position: (14, 24), gelangt nach: (15, 24), 2.0
# Aktuelle Position: (24, 24), gelangt nach: (23, 24), 1.0
# Aktuelle Position: (11, 26), gelangt nach: (11, 25), 3.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: (23, 46), gelangt nach: (24, 46), 2.0
# Aktuelle Position: (13, 25), gelangt nach: (13, 25), 0.0
# [ 60] In goal: [4, 5]
# Aktuelle Position: (33, 43), gelangt nach: (33, 43), 0.0
# Aktuelle Position: (15, 24), gelangt nach: (15, 24), 0.0
# Aktuelle Position: (24, 24), gelangt nach: (23, 24), 2.0
# Aktuelle Position: (11, 25), gelangt nach: (11, 25), 0.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: (24, 46), gelangt nach: (24, 46), 0.0
# Aktuelle Position: (13, 25), gelangt nach: (13, 25), 0.0
# [ 61] In goal: [4, 5]
# Aktuelle Position: (33, 43), gelangt nach: (33, 44), 1.0
# Aktuelle Position: (15, 24), gelangt nach: (15, 24), 0.0
# Aktuelle Position: (23, 24), gelangt nach: (23, 24), 0.0
# Aktuelle Position: (11, 25), gelangt nach: (11, 24), 1.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: (24, 46), gelangt nach: (25, 46), 1.0
# Aktuelle Position: (13, 25), gelangt nach: (13, 25), 0.0
# [ 62] In goal: [4, 5]
# Aktuelle Position: (33, 44), gelangt nach: (33, 44), 0.0
# Aktuelle Position: (15, 24), gelangt nach: (15, 24), 0.0
# Aktuelle Position: (23, 24), gelangt nach: (22, 24), 1.0
# Aktuelle Position: (11, 25), gelangt nach: (11, 24), 2.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: (24, 46), gelangt nach: (25, 46), 2.0
# Aktuelle Position: (13, 25), gelangt nach: (13, 25), 0.0
# [ 63] In goal: [4, 5]
# Aktuelle Position: (33, 44), gelangt nach: (32, 44), 1.0
# Aktuelle Position: (15, 24), gelangt nach: (15, 24), 0.0
# Aktuelle Position: (23, 24), gelangt nach: (22, 24), 2.0
# Aktuelle Position: (11, 25), gelangt nach: (11, 24), 3.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: (25, 46), gelangt nach: (25, 46), 0.0
# Aktuelle Position: (13, 25), gelangt nach: (13, 25), 0.0
# [ 64] In goal: [4, 5]
# Aktuelle Position: (32, 44), gelangt nach: (32, 44), 0.0
# Aktuelle Position: (15, 24), gelangt nach: (15, 24), 0.0
# Aktuelle Position: (22, 24), gelangt nach: (22, 24), 0.0
# Aktuelle Position: (11, 24), gelangt nach: (11, 24), 0.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: (25, 46), gelangt nach: (26, 46), 1.0
# Aktuelle Position: (13, 25), gelangt nach: (13, 25), 0.0
# [ 65] In goal: [4, 5]
# Aktuelle Position: (32, 44), gelangt nach: (31, 44), 1.0
# Aktuelle Position: (15, 24), gelangt nach: (15, 23), 1.0
# Aktuelle Position: (22, 24), gelangt nach: (21, 24), 1.0
# Aktuelle Position: (11, 24), gelangt nach: (12, 24), 1.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: (25, 46), gelangt nach: (26, 46), 2.0
# Aktuelle Position: (13, 25), gelangt nach: (13, 25), 0.0
# [ 66] In goal: [4, 5]
# Aktuelle Position: (31, 44), gelangt nach: (31, 44), 0.0
# Aktuelle Position: (15, 24), gelangt nach: (15, 23), 2.0
# Aktuelle Position: (22, 24), gelangt nach: (21, 24), 2.0
# Aktuelle Position: (11, 24), gelangt nach: (12, 24), 2.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: (26, 46), gelangt nach: (26, 46), 0.0
# Aktuelle Position: (13, 25), gelangt nach: (13, 25), 0.0
# [ 67] In goal: [4, 5]
# Aktuelle Position: (31, 44), gelangt nach: (30, 44), 1.0
# Aktuelle Position: (15, 23), gelangt nach: (15, 23), 0.0
# Aktuelle Position: (21, 24), gelangt nach: (21, 24), 0.0
# Aktuelle Position: (11, 24), gelangt nach: (12, 24), 3.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: (26, 46), gelangt nach: (27, 46), 1.0
# Aktuelle Position: (13, 25), gelangt nach: (13, 25), 0.0
# [ 68] In goal: [4, 5]
# Aktuelle Position: (30, 44), gelangt nach: (30, 44), 0.0
# Aktuelle Position: (15, 23), gelangt nach: (16, 23), 1.0
# Aktuelle Position: (21, 24), gelangt nach: (20, 24), 1.0
# Aktuelle Position: (12, 24), gelangt nach: (12, 24), 0.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: (26, 46), gelangt nach: (27, 46), 2.0
# Aktuelle Position: (13, 25), gelangt nach: (13, 25), 0.0
# [ 69] In goal: [4, 5]
# Aktuelle Position: (30, 44), gelangt nach: (29, 44), 1.0
# Aktuelle Position: (15, 23), gelangt nach: (16, 23), 2.0
# Aktuelle Position: (21, 24), gelangt nach: (20, 24), 2.0
# Aktuelle Position: (12, 24), gelangt nach: (13, 24), 1.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: (27, 46), gelangt nach: (27, 46), 0.0
# Aktuelle Position: (13, 25), gelangt nach: (13, 25), 0.0
# [ 70] In goal: [4, 5]
# Aktuelle Position: (29, 44), gelangt nach: (29, 44), 0.0
# Aktuelle Position: (16, 23), gelangt nach: (16, 23), 0.0
# Aktuelle Position: (20, 24), gelangt nach: (20, 24), 0.0
# Aktuelle Position: (12, 24), gelangt nach: (13, 24), 2.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: (27, 46), gelangt nach: (28, 46), 1.0
# Aktuelle Position: (13, 25), gelangt nach: (13, 25), 0.0
# [ 71] In goal: [4, 5]
# Aktuelle Position: (29, 44), gelangt nach: (28, 44), 1.0
# Aktuelle Position: (16, 23), gelangt nach: (17, 23), 1.0
# Aktuelle Position: (20, 24), gelangt nach: (19, 24), 1.0
# Aktuelle Position: (12, 24), gelangt nach: (13, 24), 3.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: (27, 46), gelangt nach: (28, 46), 2.0
# Aktuelle Position: (13, 25), gelangt nach: (13, 24), 1.0
# [ 72] In goal: [4, 5]
# Aktuelle Position: (28, 44), gelangt nach: (28, 44), 0.0
# Aktuelle Position: (16, 23), gelangt nach: (17, 23), 2.0
# Aktuelle Position: (20, 24), gelangt nach: (19, 24), 2.0
# Aktuelle Position: (13, 24), gelangt nach: (13, 24), 0.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: (28, 46), gelangt nach: (28, 46), 0.0
# Aktuelle Position: (13, 25), gelangt nach: (13, 24), 2.0
# [ 73] In goal: [4, 5]
# Aktuelle Position: (28, 44), gelangt nach: (27, 44), 1.0
# Aktuelle Position: (17, 23), gelangt nach: (17, 23), 0.0
# Aktuelle Position: (19, 24), gelangt nach: (19, 24), 0.0
# Aktuelle Position: (13, 24), gelangt nach: (14, 24), 1.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: (28, 46), gelangt nach: (29, 46), 1.0
# Aktuelle Position: (13, 25), gelangt nach: (13, 24), 3.0
# [ 74] In goal: [4, 5]
# Aktuelle Position: (27, 44), gelangt nach: (27, 44), 0.0
# Aktuelle Position: (17, 23), gelangt nach: (18, 23), 1.0
# Aktuelle Position: (19, 24), gelangt nach: (18, 24), 1.0
# Aktuelle Position: (13, 24), gelangt nach: (14, 24), 2.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: (28, 46), gelangt nach: (29, 46), 2.0
# Aktuelle Position: (13, 25), gelangt nach: (13, 24), 4.0
# [ 75] In goal: [4, 5]
# Aktuelle Position: (27, 44), gelangt nach: (26, 44), 1.0
# Aktuelle Position: (17, 23), gelangt nach: (18, 23), 2.0
# Aktuelle Position: (19, 24), gelangt nach: (18, 24), 2.0
# Aktuelle Position: (13, 24), gelangt nach: (14, 24), 3.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: (29, 46), gelangt nach: (29, 46), 0.0
# Aktuelle Position: (13, 25), gelangt nach: (13, 24), 5.0
# [ 76] In goal: [4, 5]
# Aktuelle Position: (26, 44), gelangt nach: (26, 44), 0.0
# Aktuelle Position: (18, 23), gelangt nach: (18, 23), 0.0
# Aktuelle Position: (18, 24), gelangt nach: (18, 24), 0.0
# Aktuelle Position: (14, 24), gelangt nach: (14, 24), 0.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: (29, 46), gelangt nach: (30, 46), 1.0
# Aktuelle Position: (13, 24), gelangt nach: (13, 24), 0.0
# [ 77] In goal: [4, 5]
# Aktuelle Position: (26, 44), gelangt nach: (25, 44), 1.0
# Aktuelle Position: (18, 23), gelangt nach: (19, 23), 1.0
# Aktuelle Position: (18, 24), gelangt nach: (17, 24), 1.0
# Aktuelle Position: (14, 24), gelangt nach: (15, 24), 1.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: (29, 46), gelangt nach: (30, 46), 2.0
# Aktuelle Position: (13, 24), gelangt nach: (12, 24), 1.0
# [ 78] In goal: [4, 5]
# Aktuelle Position: (25, 44), gelangt nach: (25, 44), 0.0
# Aktuelle Position: (18, 23), gelangt nach: (19, 23), 2.0
# Aktuelle Position: (18, 24), gelangt nach: (17, 24), 2.0
# Aktuelle Position: (14, 24), gelangt nach: (15, 24), 2.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: (30, 46), gelangt nach: (30, 46), 0.0
# Aktuelle Position: (13, 24), gelangt nach: (12, 24), 2.0
# [ 79] In goal: [4, 5]
# Aktuelle Position: (25, 44), gelangt nach: (24, 44), 1.0
# Aktuelle Position: (19, 23), gelangt nach: (19, 23), 0.0
# Aktuelle Position: (17, 24), gelangt nach: (17, 24), 0.0
# Aktuelle Position: (14, 24), gelangt nach: (15, 24), 3.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: (30, 46), gelangt nach: (31, 46), 1.0
# Aktuelle Position: (13, 24), gelangt nach: (12, 24), 3.0
# [ 80] In goal: [4, 5]
# Aktuelle Position: (24, 44), gelangt nach: (24, 44), 0.0
# Aktuelle Position: (19, 23), gelangt nach: (19, 24), 1.0
# Aktuelle Position: (17, 24), gelangt nach: (16, 24), 1.0
# Aktuelle Position: (15, 24), gelangt nach: (15, 24), 0.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: (30, 46), gelangt nach: (31, 46), 2.0
# Aktuelle Position: (12, 24), gelangt nach: (12, 24), 0.0
# [ 81] In goal: [4, 5]
# Aktuelle Position: (24, 44), gelangt nach: (23, 44), 1.0
# Aktuelle Position: (19, 23), gelangt nach: (19, 24), 2.0
# Aktuelle Position: (17, 24), gelangt nach: (16, 24), 2.0
# Aktuelle Position: (15, 24), gelangt nach: (15, 23), 1.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: (31, 46), gelangt nach: (31, 46), 0.0
# Aktuelle Position: (12, 24), gelangt nach: (11, 24), 1.0
# [ 82] In goal: [4, 5]
# Aktuelle Position: (23, 44), gelangt nach: (23, 44), 0.0
# Aktuelle Position: (19, 24), gelangt nach: (19, 24), 0.0
# Aktuelle Position: (16, 24), gelangt nach: (16, 24), 0.0
# Aktuelle Position: (15, 24), gelangt nach: (15, 23), 2.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: (31, 46), gelangt nach: (32, 46), 1.0
# Aktuelle Position: (12, 24), gelangt nach: (11, 24), 2.0
# [ 83] In goal: [4, 5]
# Aktuelle Position: (23, 44), gelangt nach: (22, 44), 1.0
# Aktuelle Position: (19, 24), gelangt nach: (20, 24), 1.0
# Aktuelle Position: (16, 24), gelangt nach: (15, 24), 1.0
# Aktuelle Position: (15, 24), gelangt nach: (15, 23), 3.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: (31, 46), gelangt nach: (32, 46), 2.0
# Aktuelle Position: (12, 24), gelangt nach: (11, 24), 3.0
# [ 84] In goal: [4, 5]
# Aktuelle Position: (22, 44), gelangt nach: (22, 44), 0.0
# Aktuelle Position: (19, 24), gelangt nach: (20, 24), 2.0
# Aktuelle Position: (16, 24), gelangt nach: (15, 24), 2.0
# Aktuelle Position: (15, 23), gelangt nach: (15, 23), 0.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: (32, 46), gelangt nach: (32, 46), 0.0
# Aktuelle Position: (11, 24), gelangt nach: (11, 24), 0.0
# [ 85] In goal: [4, 5]
# Aktuelle Position: (22, 44), gelangt nach: (21, 44), 1.0
# Aktuelle Position: (20, 24), gelangt nach: (20, 24), 0.0
# Aktuelle Position: (15, 24), gelangt nach: (15, 24), 0.0
# Aktuelle Position: (15, 23), gelangt nach: (16, 23), 1.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: (32, 46), gelangt nach: (33, 46), 1.0
# Aktuelle Position: (11, 24), gelangt nach: (11, 25), 1.0
# [ 86] In goal: [4, 5]
# Aktuelle Position: (21, 44), gelangt nach: (21, 44), 0.0
# Aktuelle Position: (20, 24), gelangt nach: (21, 24), 1.0
# Aktuelle Position: (15, 24), gelangt nach: (14, 24), 1.0
# Aktuelle Position: (15, 23), gelangt nach: (16, 23), 2.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: (32, 46), gelangt nach: (33, 46), 2.0
# Aktuelle Position: (11, 24), gelangt nach: (11, 25), 2.0
# [ 87] In goal: [4, 5]
# Aktuelle Position: (21, 44), gelangt nach: (20, 44), 1.0
# Aktuelle Position: (20, 24), gelangt nach: (21, 24), 2.0
# Aktuelle Position: (15, 24), gelangt nach: (14, 24), 2.0
# Aktuelle Position: (15, 23), gelangt nach: (16, 23), 3.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: (33, 46), gelangt nach: (33, 46), 0.0
# Aktuelle Position: (11, 24), gelangt nach: (11, 25), 3.0
# [ 88] In goal: [4, 5]
# Aktuelle Position: (20, 44), gelangt nach: (20, 44), 0.0
# Aktuelle Position: (21, 24), gelangt nach: (21, 24), 0.0
# Aktuelle Position: (14, 24), gelangt nach: (14, 24), 0.0
# Aktuelle Position: (16, 23), gelangt nach: (16, 23), 0.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: (33, 46), gelangt nach: (33, 45), 1.0
# Aktuelle Position: (11, 25), gelangt nach: (11, 25), 0.0
# [ 89] In goal: [4, 5]
# Aktuelle Position: (20, 44), gelangt nach: (19, 44), 1.0
# Aktuelle Position: (21, 24), gelangt nach: (22, 24), 1.0
# Aktuelle Position: (14, 24), gelangt nach: (13, 24), 1.0
# Aktuelle Position: (16, 23), gelangt nach: (17, 23), 1.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: (33, 46), gelangt nach: (33, 45), 2.0
# Aktuelle Position: (11, 25), gelangt nach: (11, 26), 1.0
# [ 90] In goal: [4, 5]
# Aktuelle Position: (19, 44), gelangt nach: (19, 44), 0.0
# Aktuelle Position: (21, 24), gelangt nach: (22, 24), 2.0
# Aktuelle Position: (14, 24), gelangt nach: (13, 24), 2.0
# Aktuelle Position: (16, 23), gelangt nach: (17, 23), 2.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: (33, 45), gelangt nach: (33, 45), 0.0
# Aktuelle Position: (11, 25), gelangt nach: (11, 26), 2.0
# [ 91] In goal: [4, 5]
# Aktuelle Position: (19, 44), gelangt nach: (18, 44), 1.0
# Aktuelle Position: (22, 24), gelangt nach: (22, 24), 0.0
# Aktuelle Position: (13, 24), gelangt nach: (13, 24), 0.0
# Aktuelle Position: (16, 23), gelangt nach: (17, 23), 3.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: (33, 45), gelangt nach: (33, 44), 1.0
# Aktuelle Position: (11, 25), gelangt nach: (11, 26), 3.0
# [ 92] In goal: [4, 5]
# Aktuelle Position: (18, 44), gelangt nach: (18, 44), 0.0
# Aktuelle Position: (22, 24), gelangt nach: (23, 24), 1.0
# Aktuelle Position: (13, 24), gelangt nach: (12, 24), 1.0
# Aktuelle Position: (17, 23), gelangt nach: (17, 23), 0.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: (33, 45), gelangt nach: (33, 44), 2.0
# Aktuelle Position: (11, 26), gelangt nach: (11, 26), 0.0
# [ 93] In goal: [4, 5]
# Aktuelle Position: (18, 44), gelangt nach: (17, 44), 1.0
# Aktuelle Position: (22, 24), gelangt nach: (23, 24), 2.0
# Aktuelle Position: (13, 24), gelangt nach: (12, 24), 2.0
# Aktuelle Position: (17, 23), gelangt nach: (18, 23), 1.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: (33, 44), gelangt nach: (33, 44), 0.0
# Aktuelle Position: (11, 26), gelangt nach: (11, 27), 1.0
# [ 94] In goal: [4, 5]
# Aktuelle Position: (17, 44), gelangt nach: (17, 44), 0.0
# Aktuelle Position: (23, 24), gelangt nach: (23, 24), 0.0
# Aktuelle Position: (12, 24), gelangt nach: (12, 24), 0.0
# Aktuelle Position: (17, 23), gelangt nach: (18, 23), 2.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: (33, 44), gelangt nach: (33, 43), 1.0
# Aktuelle Position: (11, 26), gelangt nach: (11, 27), 2.0
# [ 95] In goal: [4, 5]
# Aktuelle Position: (17, 44), gelangt nach: (17, 45), 1.0
# Aktuelle Position: (23, 24), gelangt nach: (24, 24), 1.0
# Aktuelle Position: (12, 24), gelangt nach: (11, 24), 1.0
# Aktuelle Position: (17, 23), gelangt nach: (18, 23), 3.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: (33, 44), gelangt nach: (33, 43), 2.0
# Aktuelle Position: (11, 26), gelangt nach: (11, 27), 3.0
# [ 96] In goal: [4, 5]
# Aktuelle Position: (17, 45), gelangt nach: (17, 45), 0.0
# Aktuelle Position: (23, 24), gelangt nach: (24, 24), 2.0
# Aktuelle Position: (12, 24), gelangt nach: (11, 24), 2.0
# Aktuelle Position: (18, 23), gelangt nach: (18, 23), 0.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: (33, 43), gelangt nach: (33, 43), 0.0
# Aktuelle Position: (11, 27), gelangt nach: (11, 27), 0.0
# [ 97] In goal: [4, 5]
# Aktuelle Position: (17, 45), gelangt nach: (17, 46), 1.0
# Aktuelle Position: (24, 24), gelangt nach: (24, 24), 0.0
# Aktuelle Position: (11, 24), gelangt nach: (11, 24), 0.0
# Aktuelle Position: (18, 23), gelangt nach: (19, 23), 1.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: (33, 43), gelangt nach: (33, 42), 1.0
# Aktuelle Position: (11, 27), gelangt nach: (11, 28), 1.0
# [ 98] In goal: [4, 5]
# Aktuelle Position: (17, 46), gelangt nach: (17, 46), 0.0
# Aktuelle Position: (24, 24), gelangt nach: (25, 24), 1.0
# Aktuelle Position: (11, 24), gelangt nach: (11, 25), 1.0
# Aktuelle Position: (18, 23), gelangt nach: (19, 23), 2.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: (33, 43), gelangt nach: (33, 42), 2.0
# Aktuelle Position: (11, 27), gelangt nach: (11, 28), 2.0
# [ 99] In goal: [4, 5]
# Aktuelle Position: (17, 46), gelangt nach: (16, 46), 1.0
# Aktuelle Position: (24, 24), gelangt nach: (25, 24), 2.0
# Aktuelle Position: (11, 24), gelangt nach: (11, 25), 2.0
# Aktuelle Position: (18, 23), gelangt nach: (19, 23), 3.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: (33, 42), gelangt nach: (33, 42), 0.0
# Aktuelle Position: (11, 27), gelangt nach: (11, 28), 3.0
# [100] In goal: [4, 5]
# Aktuelle Position: (16, 46), gelangt nach: (16, 46), 0.0
# Aktuelle Position: (25, 24), gelangt nach: (25, 24), 0.0
# Aktuelle Position: (11, 25), gelangt nach: (11, 25), 0.0
# Aktuelle Position: (19, 23), gelangt nach: (19, 23), 0.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: (33, 42), gelangt nach: (33, 41), 1.0
# Aktuelle Position: (11, 28), gelangt nach: (11, 28), 0.0
# ...
# Aktuelle Position: None, gelangt nach: (13, 40), 0.0
# [234] In goal: [0, 4, 5, 7]
# Aktuelle Position: None, gelangt nach: (11, 40), 0.0
# Aktuelle Position: (37, 30), gelangt nach: (37, 30), 0.0
# Aktuelle Position: (32, 44), gelangt nach: (33, 44), 2.0
# Aktuelle Position: (24, 24), gelangt nach: (24, 24), 0.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: (18, 26), gelangt nach: (18, 26), 0.0
# Aktuelle Position: None, gelangt nach: (13, 40), 0.0
# [235] In goal: [0, 4, 5, 7]
# Aktuelle Position: None, gelangt nach: (11, 40), 0.0
# Aktuelle Position: (37, 30), gelangt nach: (36, 30), 1.0
# Aktuelle Position: (33, 44), gelangt nach: (33, 44), 0.0
# Aktuelle Position: (24, 24), gelangt nach: (25, 24), 1.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: (18, 26), gelangt nach: (17, 26), 1.0
# Aktuelle Position: None, gelangt nach: (13, 40), 0.0
# [236] In goal: [0, 4, 5, 7]
# Aktuelle Position: None, gelangt nach: (11, 40), 0.0
# Aktuelle Position: (37, 30), gelangt nach: (36, 30), 2.0
# Aktuelle Position: (33, 44), gelangt nach: (34, 44), 1.0
# Aktuelle Position: (24, 24), gelangt nach: (25, 24), 2.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: (18, 26), gelangt nach: (17, 26), 2.0
# Aktuelle Position: None, gelangt nach: (13, 40), 0.0
# [237] In goal: [0, 4, 5, 6, 7]
# Aktuelle Position: None, gelangt nach: (11, 40), 0.0
# Aktuelle Position: (36, 30), gelangt nach: (36, 30), 0.0
# Aktuelle Position: (33, 44), gelangt nach: (34, 44), 2.0
# Aktuelle Position: (24, 24), gelangt nach: (25, 24), 3.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: None, gelangt nach: (17, 26), 0.0
# Aktuelle Position: None, gelangt nach: (13, 40), 0.0
# [238] In goal: [0, 4, 5, 6, 7]
# Aktuelle Position: None, gelangt nach: (11, 40), 0.0
# Aktuelle Position: (36, 30), gelangt nach: (35, 30), 1.0
# Aktuelle Position: (34, 44), gelangt nach: (34, 44), 0.0
# Aktuelle Position: (25, 24), gelangt nach: (25, 24), 0.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: None, gelangt nach: (17, 26), 0.0
# Aktuelle Position: None, gelangt nach: (13, 40), 0.0
# [239] In goal: [0, 4, 5, 6, 7]
# Aktuelle Position: None, gelangt nach: (11, 40), 0.0
# Aktuelle Position: (36, 30), gelangt nach: (35, 30), 2.0
# Aktuelle Position: (34, 44), gelangt nach: (34, 43), 1.0
# Aktuelle Position: (25, 24), gelangt nach: (26, 24), 1.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: None, gelangt nach: (17, 26), 0.0
# Aktuelle Position: None, gelangt nach: (13, 40), 0.0
# [240] In goal: [0, 4, 5, 6, 7]
# Aktuelle Position: None, gelangt nach: (11, 40), 0.0
# Aktuelle Position: (35, 30), gelangt nach: (35, 30), 0.0
# Aktuelle Position: (34, 44), gelangt nach: (34, 43), 2.0
# Aktuelle Position: (25, 24), gelangt nach: (26, 24), 2.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: None, gelangt nach: (17, 26), 0.0
# Aktuelle Position: None, gelangt nach: (13, 40), 0.0
# [241] In goal: [0, 4, 5, 6, 7]
# Aktuelle Position: None, gelangt nach: (11, 40), 0.0
# Aktuelle Position: (35, 30), gelangt nach: (35, 31), 1.0
# Aktuelle Position: (34, 43), gelangt nach: (34, 43), 0.0
# Aktuelle Position: (25, 24), gelangt nach: (26, 24), 3.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: None, gelangt nach: (17, 26), 0.0
# Aktuelle Position: None, gelangt nach: (13, 40), 0.0
# [242] In goal: [0, 4, 5, 6, 7]
# Aktuelle Position: None, gelangt nach: (11, 40), 0.0
# Aktuelle Position: (35, 30), gelangt nach: (35, 31), 2.0
# Aktuelle Position: (34, 43), gelangt nach: (34, 42), 1.0
# Aktuelle Position: (26, 24), gelangt nach: (26, 24), 0.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: None, gelangt nach: (17, 26), 0.0
# Aktuelle Position: None, gelangt nach: (13, 40), 0.0
# [243] In goal: [0, 4, 5, 6, 7]
# Aktuelle Position: None, gelangt nach: (11, 40), 0.0
# Aktuelle Position: (35, 31), gelangt nach: (35, 31), 0.0
# Aktuelle Position: (34, 43), gelangt nach: (34, 42), 2.0
# Aktuelle Position: (26, 24), gelangt nach: (27, 24), 1.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: None, gelangt nach: (17, 26), 0.0
# Aktuelle Position: None, gelangt nach: (13, 40), 0.0
# [244] In goal: [0, 4, 5, 6, 7]
# Aktuelle Position: None, gelangt nach: (11, 40), 0.0
# Aktuelle Position: (35, 31), gelangt nach: (35, 32), 1.0
# Aktuelle Position: (34, 42), gelangt nach: (34, 42), 0.0
# Aktuelle Position: (26, 24), gelangt nach: (27, 24), 2.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: None, gelangt nach: (17, 26), 0.0
# Aktuelle Position: None, gelangt nach: (13, 40), 0.0
# [245] In goal: [0, 4, 5, 6, 7]
# Aktuelle Position: None, gelangt nach: (11, 40), 0.0
# Aktuelle Position: (35, 31), gelangt nach: (35, 32), 2.0
# Aktuelle Position: (34, 42), gelangt nach: (34, 41), 1.0
# Aktuelle Position: (26, 24), gelangt nach: (27, 24), 3.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: None, gelangt nach: (17, 26), 0.0
# Aktuelle Position: None, gelangt nach: (13, 40), 0.0
# [246] In goal: [0, 4, 5, 6, 7]
# Aktuelle Position: None, gelangt nach: (11, 40), 0.0
# Aktuelle Position: (35, 32), gelangt nach: (35, 32), 0.0
# Aktuelle Position: (34, 42), gelangt nach: (34, 41), 2.0
# Aktuelle Position: (27, 24), gelangt nach: (27, 24), 0.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: None, gelangt nach: (17, 26), 0.0
# Aktuelle Position: None, gelangt nach: (13, 40), 0.0
# [247] In goal: [0, 4, 5, 6, 7]
# Aktuelle Position: None, gelangt nach: (11, 40), 0.0
# Aktuelle Position: (35, 32), gelangt nach: (35, 33), 1.0
# Aktuelle Position: (34, 41), gelangt nach: (34, 41), 0.0
# Aktuelle Position: (27, 24), gelangt nach: (28, 24), 1.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: None, gelangt nach: (17, 26), 0.0
# Aktuelle Position: None, gelangt nach: (13, 40), 0.0
# [248] In goal: [0, 4, 5, 6, 7]
# Aktuelle Position: None, gelangt nach: (11, 40), 0.0
# Aktuelle Position: (35, 32), gelangt nach: (35, 33), 2.0
# Aktuelle Position: (34, 41), gelangt nach: (34, 40), 1.0
# Aktuelle Position: (27, 24), gelangt nach: (28, 24), 2.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: None, gelangt nach: (17, 26), 0.0
# Aktuelle Position: None, gelangt nach: (13, 40), 0.0
# [249] In goal: [0, 4, 5, 6, 7]
# Aktuelle Position: None, gelangt nach: (11, 40), 0.0
# Aktuelle Position: (35, 33), gelangt nach: (35, 33), 0.0
# Aktuelle Position: (34, 41), gelangt nach: (34, 40), 2.0
# Aktuelle Position: (27, 24), gelangt nach: (28, 24), 3.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: None, gelangt nach: (17, 26), 0.0
# Aktuelle Position: None, gelangt nach: (13, 40), 0.0
# [250] In goal: [0, 4, 5, 6, 7]
# Aktuelle Position: None, gelangt nach: (11, 40), 0.0
# Aktuelle Position: (35, 33), gelangt nach: (35, 34), 1.0
# Aktuelle Position: (34, 40), gelangt nach: (34, 40), 0.0
# Aktuelle Position: (28, 24), gelangt nach: (28, 24), 0.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: None, gelangt nach: (17, 26), 0.0
# Aktuelle Position: None, gelangt nach: (13, 40), 0.0
# [251] In goal: [0, 4, 5, 6, 7]
# Aktuelle Position: None, gelangt nach: (11, 40), 0.0
# Aktuelle Position: (35, 33), gelangt nach: (35, 34), 2.0
# Aktuelle Position: (34, 40), gelangt nach: (34, 39), 1.0
# Aktuelle Position: (28, 24), gelangt nach: (29, 24), 1.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: None, gelangt nach: (17, 26), 0.0
# Aktuelle Position: None, gelangt nach: (13, 40), 0.0
# [252] In goal: [0, 4, 5, 6, 7]
# Aktuelle Position: None, gelangt nach: (11, 40), 0.0
# Aktuelle Position: (35, 34), gelangt nach: (35, 34), 0.0
# Aktuelle Position: (34, 40), gelangt nach: (34, 39), 2.0
# Aktuelle Position: (28, 24), gelangt nach: (29, 24), 2.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: None, gelangt nach: (17, 26), 0.0
# Aktuelle Position: None, gelangt nach: (13, 40), 0.0
# [253] In goal: [0, 4, 5, 6, 7]
# Aktuelle Position: None, gelangt nach: (11, 40), 0.0
# Aktuelle Position: (35, 34), gelangt nach: (35, 35), 1.0
# Aktuelle Position: (34, 39), gelangt nach: (34, 39), 0.0
# Aktuelle Position: (28, 24), gelangt nach: (29, 24), 3.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: None, gelangt nach: (17, 26), 0.0
# Aktuelle Position: None, gelangt nach: (13, 40), 0.0
# [254] In goal: [0, 4, 5, 6, 7]
# Aktuelle Position: None, gelangt nach: (11, 40), 0.0
# Aktuelle Position: (35, 34), gelangt nach: (35, 35), 2.0
# Aktuelle Position: (34, 39), gelangt nach: (34, 38), 1.0
# Aktuelle Position: (29, 24), gelangt nach: (29, 24), 0.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: None, gelangt nach: (17, 26), 0.0
# Aktuelle Position: None, gelangt nach: (13, 40), 0.0
# [255] In goal: [0, 4, 5, 6, 7]
# Aktuelle Position: None, gelangt nach: (11, 40), 0.0
# Aktuelle Position: (35, 35), gelangt nach: (35, 35), 0.0
# Aktuelle Position: (34, 39), gelangt nach: (34, 38), 2.0
# Aktuelle Position: (29, 24), gelangt nach: (30, 24), 1.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: None, gelangt nach: (17, 26), 0.0
# Aktuelle Position: None, gelangt nach: (13, 40), 0.0
# [256] In goal: [0, 2, 4, 5, 6, 7]
# Aktuelle Position: None, gelangt nach: (11, 40), 0.0
# Aktuelle Position: (35, 35), gelangt nach: (35, 36), 1.0
# Aktuelle Position: None, gelangt nach: (34, 38), 0.0
# Aktuelle Position: (29, 24), gelangt nach: (30, 24), 2.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: None, gelangt nach: (17, 26), 0.0
# Aktuelle Position: None, gelangt nach: (13, 40), 0.0
# [257] In goal: [0, 2, 4, 5, 6, 7]
# Aktuelle Position: None, gelangt nach: (11, 40), 0.0
# Aktuelle Position: (35, 35), gelangt nach: (35, 36), 2.0
# Aktuelle Position: None, gelangt nach: (34, 38), 0.0
# Aktuelle Position: (29, 24), gelangt nach: (30, 24), 3.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: None, gelangt nach: (17, 26), 0.0
# Aktuelle Position: None, gelangt nach: (13, 40), 0.0
# [258] In goal: [0, 2, 4, 5, 6, 7]
# Aktuelle Position: None, gelangt nach: (11, 40), 0.0
# Aktuelle Position: (35, 36), gelangt nach: (35, 36), 0.0
# Aktuelle Position: None, gelangt nach: (34, 38), 0.0
# Aktuelle Position: (30, 24), gelangt nach: (30, 24), 0.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: None, gelangt nach: (17, 26), 0.0
# Aktuelle Position: None, gelangt nach: (13, 40), 0.0
# [259] In goal: [0, 2, 4, 5, 6, 7]
# Aktuelle Position: None, gelangt nach: (11, 40), 0.0
# Aktuelle Position: (35, 36), gelangt nach: (36, 36), 1.0
# Aktuelle Position: None, gelangt nach: (34, 38), 0.0
# Aktuelle Position: (30, 24), gelangt nach: (31, 24), 1.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: None, gelangt nach: (17, 26), 0.0
# Aktuelle Position: None, gelangt nach: (13, 40), 0.0
# [260] In goal: [0, 2, 4, 5, 6, 7]
# Aktuelle Position: None, gelangt nach: (11, 40), 0.0
# Aktuelle Position: (35, 36), gelangt nach: (36, 36), 2.0
# Aktuelle Position: None, gelangt nach: (34, 38), 0.0
# Aktuelle Position: (30, 24), gelangt nach: (31, 24), 2.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: None, gelangt nach: (17, 26), 0.0
# Aktuelle Position: None, gelangt nach: (13, 40), 0.0
# [261] In goal: [0, 2, 4, 5, 6, 7]
# Aktuelle Position: None, gelangt nach: (11, 40), 0.0
# Aktuelle Position: (36, 36), gelangt nach: (36, 36), 0.0
# Aktuelle Position: None, gelangt nach: (34, 38), 0.0
# Aktuelle Position: (30, 24), gelangt nach: (31, 24), 3.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: None, gelangt nach: (17, 26), 0.0
# Aktuelle Position: None, gelangt nach: (13, 40), 0.0
# [262] In goal: [0, 2, 4, 5, 6, 7]
# Aktuelle Position: None, gelangt nach: (11, 40), 0.0
# Aktuelle Position: (36, 36), gelangt nach: (36, 37), 1.0
# Aktuelle Position: None, gelangt nach: (34, 38), 0.0
# Aktuelle Position: (31, 24), gelangt nach: (31, 24), 0.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: None, gelangt nach: (17, 26), 0.0
# Aktuelle Position: None, gelangt nach: (13, 40), 0.0
# [263] In goal: [0, 2, 4, 5, 6, 7]
# Aktuelle Position: None, gelangt nach: (11, 40), 0.0
# Aktuelle Position: (36, 36), gelangt nach: (36, 37), 2.0
# Aktuelle Position: None, gelangt nach: (34, 38), 0.0
# Aktuelle Position: (31, 24), gelangt nach: (32, 24), 1.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: None, gelangt nach: (17, 26), 0.0
# Aktuelle Position: None, gelangt nach: (13, 40), 0.0
# [264] In goal: [0, 2, 4, 5, 6, 7]
# Aktuelle Position: None, gelangt nach: (11, 40), 0.0
# Aktuelle Position: (36, 37), gelangt nach: (36, 37), 0.0
# Aktuelle Position: None, gelangt nach: (34, 38), 0.0
# Aktuelle Position: (31, 24), gelangt nach: (32, 24), 2.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: None, gelangt nach: (17, 26), 0.0
# Aktuelle Position: None, gelangt nach: (13, 40), 0.0
# [265] In goal: [0, 2, 4, 5, 6, 7]
# Aktuelle Position: None, gelangt nach: (11, 40), 0.0
# Aktuelle Position: (36, 37), gelangt nach: (36, 38), 1.0
# Aktuelle Position: None, gelangt nach: (34, 38), 0.0
# Aktuelle Position: (31, 24), gelangt nach: (32, 24), 3.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: None, gelangt nach: (17, 26), 0.0
# Aktuelle Position: None, gelangt nach: (13, 40), 0.0
# [266] In goal: [0, 2, 3, 4, 5, 6, 7]
# Aktuelle Position: None, gelangt nach: (11, 40), 0.0
# Aktuelle Position: (36, 37), gelangt nach: (36, 38), 2.0
# Aktuelle Position: None, gelangt nach: (34, 38), 0.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: None, gelangt nach: (17, 26), 0.0
# Aktuelle Position: None, gelangt nach: (13, 40), 0.0
# [267] In goal: [0, 1, 2, 3, 4, 5, 6, 7, '__all__']
# Aktuelle Position: None, gelangt nach: (11, 40), 0.0
# Aktuelle Position: None, gelangt nach: (36, 38), 0.0
# Aktuelle Position: None, gelangt nach: (34, 38), 0.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: None, gelangt nach: (32, 24), 0.0
# Aktuelle Position: None, gelangt nach: (17, 26), 0.0
# Aktuelle Position: None, gelangt nach: (13, 40), 0.0
#
# All Agents are in their targets! After 267 iterations.

# %%
result[0].nodes
# Out:
# [(33, 25) | Forward | t=[5-8],
#  (34, 25) | Forward | t=[9-12],
#  (34, 24) | Right   | t=[13-16],
#  (35, 24) | Left    | t=[17-20],
#  (36, 24) | Forward | t=[21-24],
#  (37, 24) | Forward | t=[25-28],
#  (38, 24) | Forward | t=[29-32],
#  (38, 25) | Left    | t=[33-36],
#  (38, 26) | Forward | t=[37-40],
#  (38, 27) | Forward | t=[41-44],
#  (38, 28) | Forward | t=[45-48],
#  (38, 29) | Forward | t=[49-52],
#  (38, 30) | Forward | t=[53-56],
#  (37, 30) | Left    | t=[57-60],
#  (36, 30) | Forward | t=[61-64],
#  (35, 30) | Forward | t=[65-68],
#  (34, 30) | Forward | t=[69-72],
#  (33, 30) | Forward | t=[73-76],
#  (33, 31) | Right   | t=[77-80],
#  (33, 32) | Forward | t=[81-84],
#  (33, 33) | Forward | t=[85-88],
#  (33, 34) | Forward | t=[89-92],
#  (33, 35) | Forward | t=[93-96],
#  (33, 36) | Forward | t=[97-100],
#  (33, 37) | Forward | t=[101-104],
#  (33, 38) | Forward | t=[105-108],
#  (33, 39) | Forward | t=[109-112],
#  (33, 40) | Forward | t=[113-116],
#  (33, 41) | Forward | t=[117-120],
#  (33, 42) | Forward | t=[121-124],
#  (33, 43) | Forward | t=[125-128],
#  (33, 44) | Forward | t=[129-132],
#  (32, 44) | Left    | t=[133-136],
#  (31, 44) | Forward | t=[137-140],
#  (30, 44) | Forward | t=[141-144],
#  (29, 44) | Forward | t=[145-148],
#  (28, 44) | Forward | t=[149-152],
#  (27, 44) | Forward | t=[153-156],
#  (26, 44) | Forward | t=[157-160],
#  (25, 44) | Forward | t=[161-164],
#  (24, 44) | Forward | t=[165-168],
#  (23, 44) | Forward | t=[169-172],
#  (22, 44) | Forward | t=[173-176],
#  (21, 44) | Forward | t=[177-180],
#  (20, 44) | Forward | t=[181-184],
#  (19, 44) | Forward | t=[185-188],
#  (18, 44) | Forward | t=[189-192],
#  (17, 44) | Forward | t=[193-196],
#  (17, 45) | Right   | t=[197-200],
#  (17, 46) | Forward | t=[201-204],
#  (16, 46) | Left    | t=[205-208],
#  (15, 46) | Forward | t=[209-212],
#  (14, 46) | Forward | t=[213-216],
#  (13, 46) | Forward | t=[217-220],
#  (12, 46) | Forward | t=[221-224],
#  (12, 45) | Left    | t=[225-228],
#  (12, 44) | Forward | t=[229-232],
#  (12, 43) | Forward | t=[233-236],
#  (11, 43) | Right   | t=[237-240],
#  (11, 42) | Left    | t=[241-244],
#  (11, 41) | Forward | t=[245-248],
#  (11, 40) | Forward | t=[249-252]]

# %%
speed_ration_map = {1.: 0.25,  # Fast passenger train
                    1. / 2.: 0.25,  # Fast freight train
                    1. / 3.: 0.25,  # Slow commuter train
                    1. / 4.: 0.25}  # Slow freight train
    
env = RailEnv(width=50,
              height=50,
              rail_generator=sparse_rail_generator(
                  max_num_cities = 5,
                  grid_mode= False,
                  max_rails_between_cities = 5,
                  max_rails_in_city = 5, 
                  seed=0
              ),
              schedule_generator=sparse_schedule_generator(speed_ration_map),
              number_of_agents=2
    )

_, info = env.reset()

# print(env.agents)

# %%
result = pp(env, info)
# Out:
# Checking if the starting positions are valid...
# Agent:  1 starting from: (10, 40) - heading to: (36, 38), speed: 3 --> in 0.004554sec
# Agent:  0 starting from: (32, 25) - heading to: (11, 40), speed: 4 --> in 0.006136sec

# %%
class NextCell():
    
    def __init__(self, position, action, cost, direction):
        self.position = position
        self.action = action
        self.cost = cost
        self.direction = direction

    def __repr__(self):
        return f"{self.position} | {action_to_str[self.action]} | {self.cost} | {direction_to_str[self.direction]}"


# Position, action, cost, direction
def calc_next_cell(position, direction, handle):            
    """
    for i in range(4):
        print(direction_to_str[i], i)
        print(calc_next_cell((33, 46), i, 6))
        print("-" * 50 + "\n")
    """
    
    possible_transitions = env.rail.get_transitions(*position, direction)

    # This should be never true when searching with the a star algorithm
    if all(d == 0 for d in possible_transitions):
        print("This Direction is not permissable!")
        return -1
    
    # Initalize the next_cells with the action when there is done nothing/waiting (4), because this is alway possible
    next_cells = [NextCell(position, 4, env.distance_map.get()[handle, position[0], position[1], direction], direction)]

    # Loop trough all the possible dirrections the agent can reach from current direction
    for d in [(direction + i) % 4 for i in range(-1, 2)]:
        
        if possible_transitions[d]:
            
            # Die neue Position, wenn man die jeweilige direction 
            new_position = get_new_position(position, d)
            
            
            # Die Distanz von einer Position zum Ziel des jeweiligen Agenten
            dist = env.distance_map.get()[handle, new_position[0], new_position[1], d]
            
            # Check the given directions and map it to the corresponding action
            if d == direction:
                next_cells.append(NextCell(new_position, 2, dist, d))

            elif (d + 1) % 4 == direction:
                next_cells.append(NextCell(new_position, 1, dist, d))
                
            elif (d - 1) % 4 == direction:
                next_cells.append(NextCell(new_position, 3, dist, d))
    
    else:
    
        # Check if the transition is an dead End
        if possible_transitions[(direction + 2) % 4] == 1:
            direction = (direction + 2) % 4

            new_position = get_new_position(position, direction)

            dist = env.distance_map.get()[handle, new_position[0], new_position[1], direction]

            next_cells.append(NextCell(new_position, 2, dist, direction))
    
    return next_cells

# %%
import heapq


class A_Star_result():
    succes = 1
    fail = 2
    
    def __init__(self, status=succes, nodes=[], iterations=-1):
        self.status = status
        self.nodes = nodes
        
        self.actions = []
        self.positions = []

        for node in nodes:
            self.actions.append(node.action)
            self.positions.append(node.position)
            
        self.iterations = iterations

    def __repr__(self):
        if self.status == A_Star_result.succes:
            return f"Succes! actions: {self.actions}, positions: {self.positions}"
        else:
            return f"No Solution! Failed in {self.iterations} iterations..."
        
    def is_empty(self):
        return len(self.actions) == 0
    
    def get_n_action(self, n):
        if n < 0 or n >= len(self.actions):
            raise "Error: Trying to get acces to an action with an undifinded timestep!"
            
        return self.actions[n]
    
    def pop(self, n=0):
        if n < 0 or n >= len(self.actions):
            raise "Error: Trying to get acces to an action with an undifinded timestep!"
        
        return (self.actions.pop(n), self.positions.pop(n))


class Node:
    def __init__(self, position, parent=None, action=None, cost=-1, direction=None, start=-1, stop=-1):
        self.position = position
        self.parent = parent
        self.action = action
        self.cost = cost
        self.direction = direction
        self.start = start
        self.stop = stop

        self.states = [(position, direction, timestamp) for timestamp in range(start, stop+1)]
    
    def __lt__(self, other):
        return self.cost < other.cost
    
    def __repr__(self):
        if self.action is not None and self.direction is not None:
            return f"{self.position} | {action_to_str[self.action]:7s} | {self.cost:3} | {direction_to_str[self.direction]:5s} | t=[{self.start}-{self.stop}]"
        elif self.action:
            return f"{self.position} | {action_to_str[self.action]:7s} | t=[{self.start}-{self.stop}]"
        else:
            return f"{self.position} | t=[{self.start}-{self.stop}]"
    
    def check_possible(self, other_obstacles):
        
        for timestamp in range(self.start, self.stop+1):
            # Get all the obstacles in the current timestamp
            res = other_obstacles.get(timestamp)

            if res is None: continue

            # Check if there is a obstacle with the same position. If there is an overlap, otherwise it is ok
            for n in res:
            
                if self.position == n: return False

        return True
            

def make_root_node(postion, direction, interval):
    return Node(postion, None, None, 0, direction, 1, interval)

def make_node(position, parent, action, cost, direction, interval):
    if action == 4:
        return Node(position, parent, action, cost, direction, parent.stop+1, parent.stop+1)
        
    return Node(position, parent, action, cost, direction, parent.stop+1, parent.stop+interval)

def extract_solution(node):
    sol = []
    
    while node.parent is not None:
        sol.append(Node(node.position, action=node.action, start=node.start, stop=node.stop))

        node = node.parent
    
    # Also append the parent (TEST)
    # sol.append(Node(node.position, action=2, start=node.start, stop=node.stop))
    return sol[::-1]

# %%
def a_star(handle, position, direction, target, other_obstacles, interval):

    open_list = []
    heapq.heappush(open_list, make_root_node(position, direction, interval))
    
    closed_list = []
    distance = {}

    i = 0
    while len(open_list) > 0:
        
        node = heapq.heappop(open_list)

        if len([state for state in node.states if state in closed_list]) == 0 or len([state for state in node.states if node.cost >= distance[state]]) == 0:
            
            # Extend all the States corresponding to the states the agent is at a certain time
            closed_list.extend(node.states)
            
            for state in node.states:
                distance[state] = node.cost
            
            # Return the calculated nodes when the target is reached
            if node.position == target: return A_Star_result(A_Star_result.succes, extract_solution(node))
        
            # List with all the subsequent cells created as nodes
            next_cells = calc_next_cell(node.position, node.direction, handle)
            succ_cells = [make_node(n.position, node, n.action, n.cost, n.direction, interval) for n in next_cells]
            
            # Check if the subsequent cells has an overlap with other obstacles to the specific interval
            app_cells = [pos_node.check_possible(other_obstacles) for pos_node in succ_cells]
    

            # Zusammenfassung: Nimm den Zeitpunkt des Stopp_moving Fehlers und lösche die Nodes, welche
            # den gleichen Zeitpunkt und die gleiche Position wie andere obsacles haben
            if app_cells[0] == False:
                
                pass  # Keine weitere Aktion und die eigene Stopp-aktion ist nicht anwendbar    
            
            # When there is a False in the rest of the applicable cells, without the first stop_moving one
            elif not all(app_cells[1:]):
                
                # Die Stopp-Aktion wird immer hinzugefügt
                heapq.heappush(open_list, succ_cells[0])

                # Alle Aktionen, die False sind werden rausgeworfen
                for n, app in enumerate(app_cells[1:]):

                    if not app: continue
                    
                    heapq.heappush(open_list, succ_cells[n+1])

            else:
                
                # If there is no stop_moving or other error, then all the next cells can get appended
                for succ in succ_cells:
                    
                    heapq.heappush(open_list, succ)

        i += 1
                
    return A_Star_result(A_Star_result.fail, iterations=i)


nodes = a_star(0, (32, 25), 2, (11, 40), {}, 2)

# %%
def calc_steps(info):
    
    lst = [int(1 / speed) for speed in info["speed"].values()]


    steps = []

    for curr_speed in range(1, max(lst)+1):

        acc = {}
        for handle, speed in enumerate(lst):

            if curr_speed <= speed:
                acc[handle] = 2
            else:
                acc[handle] = 4

        steps.append(acc)
        
    return steps


def pp(env, info):
    
    print("Checking if the starting positions are valid...")
    
    for iters in range(4):

        valid = True
        positions = []
        for handle in range(env.get_num_agents()):

            agent = env.agents[handle]

            if agent.position not in positions and agent.position is not None:
                positions.append(agent.position) 
            else:
                valid = False
                print(f"The positions for the {iters} Step is not valid. Try one more step...")
                
                steps = calc_steps(info)
                
                for step in steps:
                    _, _, _, info = env.step(step)
                
                break
                
        if valid:
            print("The positions are valid! Start searching...\n")
            break
            
    if not valid:
        print("Coudln't find valid starting positions. Try other enviroment!\n")
        return -1
    
    

    agents = []

    for handle, speed in info["speed"].items():

        heapq.heappush(agents, SearchAgent(handle, int(1 / speed)))
            
    
    schedules = {}
    seen = {}
    
    for _ in range(env.get_num_agents()):
        
        search_agent = heapq.heappop(agents)
        
        agent = env.agents[search_agent.handle]
        
        position = agent.position
        direction = agent.direction
        target = agent.target
        
        print(f"Agent: {search_agent.handle:2} starting from: {position} - heading to: {target}, speed: {search_agent.speed}", end=" --> ")

        
        time_start = time.time()
        
        # Get the path of the current agent with the already seen states
        res = a_star(search_agent.handle, position, direction, target, seen, search_agent.speed)
        
        print(f"in {time.time()-time_start:5f}sec")
        
        for timestamp in range(1, search_agent.speed+1):
            
            seen.setdefault(timestamp, []).append((position))
        

        for node in res.nodes:

            for timestamp in range(node.start, node.stop+1):

                seen.setdefault(timestamp, []).append((node.position))

        if res.status == A_Star_result.fail:
            print(f"Agent <{handle}> couldn't find an target!")
            return -1

        schedules[search_agent.handle] = res
        
    return schedules

pp(env, info)
# Out:
# Checking if the starting positions are valid...
# The positions are valid! Start searching...
#
# Agent:  1 starting from: (10, 40) - heading to: (36, 38), speed: 1 --> in 0.116139sec
# Agent:  2 starting from: (32, 23) - heading to: (34, 38), speed: 1 --> in 0.004104sec
# Agent:  3 starting from: (12, 40) - heading to: (32, 24), speed: 3 --> in 0.001908sec
# Agent:  0 starting from: (32, 25) - heading to: (11, 40), speed: 4 --> in 0.014427sec
# {1: Succes! actions: [2, 2, 1, 3, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 1, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 1, 2, 2, 2, 2, 2, 1, 2, 2, 3, 2, 2, 2, 2, 2, 3, 1, 2], positions: [(10, 39), (10, 38), (11, 38), (11, 37), (11, 36), (11, 35), (11, 34), (11, 33), (11, 32), (11, 31), (11, 30), (11, 29), (11, 28), (11, 27), (11, 26), (11, 25), (11, 24), (12, 24), (13, 24), (14, 24), (15, 24), (16, 24), (17, 24), (18, 24), (19, 24), (20, 24), (21, 24), (22, 24), (23, 24), (24, 24), (25, 24), (26, 24), (27, 24), (28, 24), (29, 24), (30, 24), (31, 24), (32, 24), (33, 24), (34, 24), (35, 24), (36, 24), (37, 24), (38, 24), (38, 25), (38, 26), (38, 27), (38, 28), (38, 29), (38, 30), (37, 30), (36, 30), (35, 30), (35, 31), (35, 32), (35, 33), (35, 34), (35, 35), (35, 36), (36, 36), (36, 37), (36, 38)],
#  2: Succes! actions: [2, 2, 2, 3, 1, 2, 2, 2, 2, 2, 2, 2, 2, 2, 4, 4, 4, 4, 4, 4, 4, 1, 3, 2, 2, 2, 3, 1, 2, 2, 2, 3, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 3, 2, 2, 2, 2, 2, 3, 1, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 3, 1, 2, 2, 2, 2, 2, 3, 2, 2, 2, 2, 2], positions: [(31, 23), (30, 23), (29, 23), (29, 24), (28, 24), (27, 24), (26, 24), (25, 24), (24, 24), (23, 24), (22, 24), (21, 24), (20, 24), (19, 24), (19, 24), (19, 24), (19, 24), (19, 24), (19, 24), (19, 24), (19, 24), (19, 23), (18, 23), (17, 23), (16, 23), (15, 23), (15, 24), (14, 24), (13, 24), (12, 24), (11, 24), (11, 25), (11, 26), (11, 27), (11, 28), (11, 29), (11, 30), (11, 31), (11, 32), (11, 33), (11, 34), (11, 35), (11, 36), (11, 37), (11, 38), (11, 39), (11, 40), (11, 41), (11, 42), (11, 43), (11, 44), (11, 45), (11, 46), (12, 46), (13, 46), (14, 46), (15, 46), (16, 46), (17, 46), (17, 45), (18, 45), (19, 45), (20, 45), (21, 45), (22, 45), (23, 45), (24, 45), (25, 45), (26, 45), (27, 45), (28, 45), (28, 44), (29, 44), (30, 44), (31, 44), (32, 44), (33, 44), (34, 44), (34, 43), (34, 42), (34, 41), (34, 40), (34, 39), (34, 38)],
#  3: Succes! actions: [2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 4, 4, 4, 4, 4, 3, 1, 2, 2, 2, 2, 2, 1, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2], positions: [(12, 39), (12, 38), (12, 37), (12, 36), (12, 35), (12, 34), (12, 33), (12, 32), (12, 31), (12, 30), (12, 30), (12, 30), (12, 30), (12, 30), (12, 30), (11, 30), (11, 29), (11, 28), (11, 27), (11, 26), (11, 25), (11, 24), (12, 24), (13, 24), (14, 24), (15, 24), (16, 24), (17, 24), (18, 24), (19, 24), (20, 24), (21, 24), (22, 24), (23, 24), (24, 24), (25, 24), (26, 24), (27, 24), (28, 24), (29, 24), (30, 24), (31, 24), (32, 24)],
#  0: Succes! actions: [2, 2, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 3, 1, 2, 2, 2, 1, 2, 2, 2, 2, 2, 1, 2, 2, 2, 2, 3, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 1, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 3, 2, 1, 2, 2, 2, 2, 1, 2, 2, 3, 1, 2, 2], positions: [(33, 25), (34, 25), (34, 25), (34, 25), (34, 25), (34, 25), (34, 25), (34, 25), (34, 25), (34, 25), (34, 25), (34, 25), (34, 25), (34, 25), (34, 25), (34, 25), (34, 25), (34, 25), (34, 25), (34, 25), (34, 25), (34, 25), (34, 25), (34, 25), (34, 25), (34, 25), (34, 25), (34, 25), (34, 25), (34, 25), (34, 25), (34, 24), (35, 24), (36, 24), (37, 24), (38, 24), (38, 25), (38, 26), (38, 27), (38, 28), (38, 29), (38, 30), (37, 30), (36, 30), (35, 30), (34, 30), (33, 30), (33, 31), (33, 32), (33, 33), (33, 34), (33, 35), (33, 36), (33, 37), (33, 38), (33, 39), (33, 40), (33, 41), (33, 42), (33, 43), (33, 44), (32, 44), (31, 44), (30, 44), (29, 44), (28, 44), (27, 44), (26, 44), (25, 44), (24, 44), (23, 44), (22, 44), (21, 44), (20, 44), (19, 44), (18, 44), (17, 44), (17, 45), (17, 46), (16, 46), (15, 46), (14, 46), (13, 46), (12, 46), (12, 45), (12, 44), (12, 43), (11, 43), (11, 42), (11, 41), (11, 40)]}

# %%
import PIL

def render_env(env):
    env_renderer = RenderTool(env, gl="PILSVG")
    
    for i in range(4):
        
        if i == 1:
            env.dev_obs_dict[i] = [(11, 37)]
        
        elif i == 6:
            env.dev_obs_dict[i] = [(10, 41), (10, 42), (11, 42), (11, 43), (11, 44), (11, 45), (11, 46), (12, 46), (13, 46), (14, 46), (15, 46), (16, 46), (17, 46), (18, 46), (19, 46), (20, 46), (21, 46), (22, 46), (23, 46), (24, 46), (25, 46), (26, 46), (27, 46), (28, 46), (29, 46), (30, 46), (31, 46), (32, 46), (33, 46), (33, 46), (33, 46), (33, 45), (33, 44), (33, 43), (33, 42), (33, 41), (33, 40), (33, 39), (33, 38), (33, 37), (33, 36), (34, 36), (34, 35), (34, 34), (34, 33), (34, 32), (34, 31), (35, 31), (36, 31), (36, 31), (37, 31), (37, 30), (38, 30), (38, 29), (38, 28), (38, 27), (38, 26), (38, 25), (38, 24), (37, 24), (36, 24), (35, 24), (34, 24), (33, 24), (32, 24), (31, 24), (30, 24), (29, 24), (28, 24), (27, 24), (26, 24), (25, 24), (24, 24), (23, 24), (22, 24), (21, 24), (21, 25), (20, 25), (19, 25), (19, 26), (18, 26), (17, 26)]
        
        else:
            env.dev_obs_dict[i] = [(0, 0)]
    
    
    
    env_renderer.render_env(show=True, frames=False, show_observations=True, show_predictions=False)

    image = env_renderer.get_image()
    pil_image = PIL.Image.fromarray(image)
    display(pil_image)
    

render_env(env)
# Out:
# <PIL.Image.Image image mode=RGBA size=504x504 at 0x7FCAE7EBA5F8>

# %%
class SearchAgent:
    
    def __init__(self, handle, speed):
        self.handle = handle
        self.speed = speed

    def __lt__(self, other):
        return self.speed < other.speed
    
    def __repr__(self):
        return f"Agent: {self.handle}, Speed: {self.speed}"

# %%
speed_ration_map = {1.: 0.25,  # Fast passenger train
                    1. / 2.: 0.25,  # Fast freight train
                    1. / 3.: 0.25,  # Slow commuter train
                    1. / 4.: 0.25}
    
env = RailEnv(width=50,
              height=50,
              rail_generator=sparse_rail_generator(
                  max_num_cities = 5,
                  grid_mode= False,
                  max_rails_between_cities = 5,
                  max_rails_in_city = 5, 
                  seed=0
              ),
              schedule_generator=sparse_schedule_generator(speed_ration_map),
              number_of_agents=4
    )

_, info = env.reset()


# Initial
_, _, _, info = env.step({i : 2 for i in range(env.get_num_agents())})

# %%
lst = [int(1 / speed) for speed in info["speed"].values()]


d = []

for curr_speed in range(1, max(lst)+1):
    
    acc = {}
    for handle, speed in enumerate(lst):
        
        if curr_speed <= speed:
            acc[handle] = 2
        else:
            acc[handle] = 4
    
    d.append(acc)
# Out:
# [{0: 2, 1: 2, 2: 2, 3: 2},
#  {0: 2, 1: 4, 2: 4, 3: 2},
#  {0: 2, 1: 4, 2: 4, 3: 2},
#  {0: 2, 1: 4, 2: 4, 3: 4}]

# %%
info["speed"].values()
# Out:
# dict_values([0.25, 1.0, 1.0, 0.3333333333333333])
